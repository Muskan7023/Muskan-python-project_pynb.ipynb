# %%
import numpy as np
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/Student Mental health.csv')

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                Timestamp Choose your gender   Age What is your course?  \
# 0         8/7/2020 12:02             Female  18.0          Engineering
# 1         8/7/2020 12:04               Male  21.0    Islamic education
# 2         8/7/2020 12:05               Male  19.0                  BIT
# 3         8/7/2020 12:06             Female  22.0                 Laws
# 4         8/7/2020 12:13               Male  23.0         Mathemathics
# ..                   ...                ...   ...                  ...
# 96   13/07/2020 19:56:49             Female  21.0                  BCS
# 97   13/07/2020 21:21:42               Male  18.0          Engineering
# 98   13/07/2020 21:22:56             Female  19.0             Nursing
# 99   13/07/2020 21:23:57             Female  23.0     Pendidikan Islam
# 100  18/07/2020 20:16:21               Male  20.0   Biomedical science
#
#     Your current year of Study What is your CGPA? Marital status  \
# ...

# %%
df.dtypes
# Out:
# Timestamp                                        object
# Choose your gender                               object
# Age                                             float64
# What is your course?                             object
# Your current year of Study                       object
# What is your CGPA?                               object
# Marital status                                   object
# Do you have Depression?                          object
# Do you have Anxiety?                             object
# Do you have Panic attack?                        object
# Did you seek any specialist for a treatment?     object
# dtype: object

# %%
df.shape
# Out:
# (101, 11)

# %%
df.isnull().sum()
# Out:
# Timestamp                                       0
# Choose your gender                              0
# Age                                             1
# What is your course?                            0
# Your current year of Study                      0
# What is your CGPA?                              0
# Marital status                                  0
# Do you have Depression?                         0
# Do you have Anxiety?                            0
# Do you have Panic attack?                       0
# Did you seek any specialist for a treatment?    0
# dtype: int64

# %%
sns.boxplot('Age',data=df)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df.replace(['Male','Female'],[0,1],inplace=True)
df.replace(['Yes','No'],[1,0],inplace=True)

# %%
df.head()
# Out:
#         Timestamp  Choose your gender   Age What is your course?  \
# 0  8/7/2020 12:02                   1  18.0          Engineering
# 1  8/7/2020 12:04                   0  21.0    Islamic education
# 2  8/7/2020 12:05                   0  19.0                  BIT
# 3  8/7/2020 12:06                   1  22.0                 Laws
# 4  8/7/2020 12:13                   0  23.0         Mathemathics
#
#   Your current year of Study What is your CGPA?  Marital status  \
# 0                     year 1        3.00 - 3.49               0
# 1                     year 2        3.00 - 3.49               0
# 2                     Year 1        3.00 - 3.49               0
# 3                     year 3        3.00 - 3.49               1
# 4                     year 4        3.00 - 3.49               0
#
#    Do you have Depression?  Do you have Anxiety?  Do you have Panic attack?  \
# 0                        1                     0                          1
# ...

# %%
df.rename(columns = {'Choose your gender': 'Gender', 'Do you have Anxiety?': 'Anxiety','What is your CGPA?': 'CGPA' ,'Your current year of Study': 'Current year of study','Do you have Depression?' : 'Depression','What is your course?': 'Course','Do you have Panic attack?': 'Panic attack','Did you seek any specialist for a treatment?': 'Specialist for a treatment'},inplace = True)

# %%
df.head()
# Out:
#         Timestamp  Gender   Age             Course Current year of study  \
# 0  8/7/2020 12:02       1  18.0        Engineering                year 1
# 1  8/7/2020 12:04       0  21.0  Islamic education                year 2
# 2  8/7/2020 12:05       0  19.0                BIT                Year 1
# 3  8/7/2020 12:06       1  22.0               Laws                year 3
# 4  8/7/2020 12:13       0  23.0       Mathemathics                year 4
#
#           CGPA  Marital status  Depression  Anxiety  Panic attack  \
# 0  3.00 - 3.49               0           1        0             1
# 1  3.00 - 3.49               0           0        1             0
# 2  3.00 - 3.49               0           1        1             1
# 3  3.00 - 3.49               1           1        0             0
# 4  3.00 - 3.49               0           0        0             0
#
#    Specialist for a treatment
# 0                           0
# 1                           0
# 2                           0
# ...

# %%
df.corr()
# Out:
#                               Gender       Age  Marital status  Depression  \
# Gender                      1.000000  0.002324        0.069389    0.143235
# Age                         0.002324  1.000000        0.104551   -0.072171
# Marital status              0.069389  0.104551        1.000000    0.595784
# Depression                  0.143235 -0.072171        0.595784    1.000000
# Anxiety                    -0.059783 -0.093661        0.092606    0.273764
# Panic attack                0.023902  0.055741        0.275909    0.246842
# Specialist for a treatment  0.052168  0.047808        0.349819    0.345105
#
#                              Anxiety  Panic attack  Specialist for a treatment
# Gender                     -0.059783      0.023902                    0.052168
# Age                        -0.093661      0.055741                    0.047808
# Marital status              0.092606      0.275909                    0.349819
# ...

# %%
#Checking correlation between columns using heatmap
sns.heatmap(df.corr(),annot=True)

# %%
#Counting the number of students by gender
gen_count = pd.DataFrame(df['Gender'].value_counts().reset_index())
gen_count.rename(columns = {'index':'Gender','Gender':'Number of Students'}, inplace=True)
gen_count.replace({1:'Female', 0:'Male'}, inplace=True)
gen_count
# Out:
#    Gender  Number of Students
# 0  Female                  75
# 1    Male                  26

# %%
#Visualisation gender distribution with pie chart
plt.figure(figsize=(20,5))
plt.title("Gender Discrimination")
plt.pie(x=df['Gender'].value_counts(),labels=['Female','male'],autopct='%1.1f%%')
plt.show()

# %%
#Descriptive statistics of course column

pd.DataFrame(df['Course'].describe()).T
# Out:
#        count unique  top freq
# Course   101     49  BCS   18

# %%
#Count the no of each unique variable
pd.DataFrame(df['Course'].value_counts()).rename(columns={'Course':'Number of Students'})
# Out:
#                          Number of Students
# BCS                                      18
# Engineering                              17
# BIT                                      10
# Biomedical science                        4
# KOE                                       4
# BENL                                      2
# Laws                                      2
# psychology                                2
# Engine                                    2
# Islamic Education                         1
# Biotechnology                             1
# engin                                     1
# Econs                                     1
# MHSC                                      1
# Malcom                                    1
# Kop                                       1
# Human Sciences                            1
# Communication                             1
# Nursing                                   1
# Diploma Nursing                           1
# ...

# %%
#descriptive statistics of age
df['Age'].describe().T
# Out:
# count    100.00000
# mean      20.53000
# std        2.49628
# min       18.00000
# 25%       18.00000
# 50%       19.00000
# 75%       23.00000
# max       24.00000
# Name: Age, dtype: float64

# %%
#Visualisation of student distribution by age with pie chart 
plt.figure(figsize=(12,6))
sns.countplot(x='Age', data=df)
plt.title("Age Distribution")
plt.show()

# %%
# Descriptive statistics of Current year of study 
 pd.DataFrame(df['Current year of study'].describe()).T
# Out:
#                       count unique     top freq
# Current year of study   101      7  year 1   41

# %%
#Counting number of students by current year of study 
current_count = pd.DataFrame(df['Current year of study'].value_counts().reset_index())
current_count.rename(columns = {'index':'Current year of  study','Current year of study':'Number of Students'}, inplace=True)
current_count
# Out:
#   Current year of  study  Number of Students
# 0                 year 1                  41
# 1                 Year 3                  19
# 2                 Year 2                  16
# 3                 year 2                  10
# 4                 year 4                   8
# 5                 year 3                   5
# 6                 Year 1                   2

# %%
# Visualisation no. of students by current year of study 
plt.figure(figsize=(10,8))
sns.countplot(x='Current year of study', data=df)
plt.xlabel(None)
plt.title("Current Year Study Distribution")
plt.show()

# %%
# Counting no of students by marital status 
mar_count = pd.DataFrame(df['Marital status'].value_counts())
mar_count.rename(columns = {'index':'Marital status','Marital status':'Number of Students'},
                 index={0: 'Non-Marital', 1:'Marital'}, inplace=True)
mar_count
# Out:
#              Number of Students
# Non-Marital                  85
# Marital                      16

# %%
# Visualisation marital status distribution using pie chart 
plt.figure(figsize=(12,6))
plt.pie(mar_count['Number of Students'], explode=(0.025,0.025), 
        labels=mar_count.index, 
        colors=['pink','skyblue'],autopct='%1.1f%%', startangle=180)
plt.title("Marital Status Distribution")
plt.show()

# %%
#Visualisation pie chart of students mental health 
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15,4))

ax1.pie(df['Depression'].value_counts(), explode=(0.025,0.025), 
            labels=("No Depression","Depression"), 
            colors=['bisque','lightcoral'], autopct='%1.2f%%', startangle=120)

ax2.pie(df['Anxiety'].value_counts(), explode=(0.025,0.025), 
            labels=("No Anxiety","Anxiety"), 
            colors=['bisque','lightcoral'], autopct='%1.2f%%', startangle=120)

ax3.pie(df['Panic attack'].value_counts(), explode=(0.025,0.025), 
            labels=("No Panic Attack","Panic attack"), 
            colors=['bisque','lightcoral'], autopct='%1.2f%%', startangle=120)

plt.suptitle("Students Mental Health Percentage")
plt.show()

# %%
Dep_treatment = df.groupby('Specialist for a treatment')[['Depression']].count()
Dep_treatment.rename(columns = {'Depression':'Number of Students (Depression)'},
                 index={0: 'No', 1:'Yes'}, inplace=True)
Dep_treatment
# Out:
#                             Number of Students (Depression)
# Specialist for a treatment
# No                                                       95
# Yes                                                       6

# %%
#Visualization of comparison between students who have depression based on treatment needs.
plt.figure(figsize=(12,6))
plt.pie(Dep_treatment['Number of Students (Depression)'], explode=(0.02,0),  
        labels=Dep_treatment.index,
        colors=['yellow','lightorange'], autopct='%1.2f%%', startangle=180)

centre_circle = plt.Circle((0,0),0.8,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.title("(Based on students who have depression)")
plt.suptitle('Seek any Specialist for Treatment?')
plt.show()

# %%
#Creating a dataframe of students who have Depression, Anxiety, and Panic Attack
DAP = df[(df["Depression"]==1) & (df["Anxiety"]==1) & (df["Panic attack"]==1)].reset_index(drop=True)
print("Students who have Depression, Anxiety, and Panic attack\n") 
DAP
# Out:
# Students who have Depression, Anxiety, and Panic attack
#              Timestamp  Gender   Age          Course Current year of study  \
# 0       8/7/2020 12:05       0  19.0             BIT                Year 1
# 1       8/7/2020 12:52       1  24.0             ENM                year 4
# 2       8/7/2020 13:07       1  18.0  Marine science                year 2
# 3       8/7/2020 13:17       1  23.0             BCS                Year 3
# 4       8/7/2020 13:58       1  24.0             BIT                Year 3
# 5       8/7/2020 14:41       1  19.0             BIT                year 1
# 6       8/7/2020 14:45       1  19.0             BIT                year 1
# 7       8/7/2020 15:48       1  20.0             koe                year 3
# 8  13/07/2020 10:11:26       1  24.0  Communication                 Year 2
# 9  13/07/2020 11:46:13       1  18.0      psychology                year 1
#
#           CGPA  Marital status  Depression  Anxiety  Panic attack  \
# ...

# %%
# Out:
#                             Number of Students (Depression)
# Specialist for a treatment
# No                                                       95
# Yes                                                       6
